# %%
import pandas as pd # used to manipulate data set
import plotly.express as px #used to visualise variables

# %%
data = pd.read_excel('/content/drive/MyDrive/Shared docs/Project lifecycle CW/Datasets/Data sets we will 100% use/Raw/Resole_Split.xlsx')

# %%
new_column_names = [
    "timestamp",
    "ethnicity",
    "nationality",
    "dependents",
    "uk_shoe_size",
    "shoe_purpose",
    "employment_status",
    "universal_credit",
    "education_training",
    "looked_after_or_care_leaver",
    "recently_released_prison",
    "seeking_asylum",
    "youth_support",
    "resole_source"
]
data.columns = new_column_names

# %%
data.info()

# %%
data.shape

# %%
data.isna().sum()/len(data)*100

# %%
for col in data.columns:
  print(col+":\n")
  print (data[col].unique())
  print("\n")
